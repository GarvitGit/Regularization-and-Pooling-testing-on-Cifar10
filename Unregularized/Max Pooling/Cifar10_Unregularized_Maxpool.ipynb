# %%
from keras.datasets import cifar10#importing dataset
import keras
from keras.models import Sequential
from keras.layers import Activation,Conv2D,BatchNormalization,Dense,Flatten,AveragePooling2D,Dropout
import matplotlib.pyplot as plt # visualization
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#downloading data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
i=50 # any random number would work between 0 and 49999
plt.imshow(x_train[i]) # To see the image
print(y_train[i]) # Corresponding output
# Out:
# [9]

# %%
# Time to change y to categorical for so that the outputs can be matched
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
model=Sequential()
# making the model
# input>conv2d>>relu>BatchNom>conv2d>relu>BatchNorm>MaxPool
model.add(Conv2D(32,(3,3),padding='same',input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

#>conv2d>>relu>BatchNom>conv2d>relu>BatchNorm>MaxPool

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

#flatten>Dense>BatchNorm>relu>softmax(output)

model.add(Flatten())
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(10,activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Checking the model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,679,658
# Trainable params: 1,678,250
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping,ReduceLROnPlateau

# Setting up callback function

early=EarlyStopping(patience=10) # if no changes are seen the model willstop training

reduce=ReduceLROnPlateau(monitor='val_acc',factor=0.5,patience=3,min_lr=0.00001,verbose=1) #if significant change is not seen
# the model will decrease the learning rate

callback=[early,reduce]

# %%
# Compiling the model
model.compile(loss='categorical_crossentropy', #loss function
              optimizer='adam', #here we are using adam optimizer
              metrics=['accuracy'])

# %%
# changing type to float
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# one value can vary upto 255
x_train /= 255
x_test /= 255

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# checking shape and initializing no of epochs and batch size
total_test=x_test.shape[0]
total_train=x_train.shape[0]
epochs=50
batch=25

# %%
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history=model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        validation_steps=total_test//batch,
                        steps_per_epoch=total_train//batch,
                        callbacks=callback,
                        workers=4)
# Out:
# Using real-time data augmentation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 1.2418 - acc: 0.5642 - val_loss: 0.9736 - val_acc: 0.6550
# Epoch 2/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.8940 - acc: 0.6849 - val_loss: 0.8238 - val_acc: 0.7138
# Epoch 3/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.7715 - acc: 0.7287 - val_loss: 0.7651 - val_acc: 0.7377
# Epoch 4/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.7000 - acc: 0.7579 - val_loss: 0.6956 - val_acc: 0.7632
# Epoch 5/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.6379 - acc: 0.7781 - val_loss: 0.7135 - val_acc: 0.7647
# Epoch 6/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.5921 - acc: 0.7932 - val_loss: 0.6408 - val_acc: 0.7805
# Epoch 7/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.5614 - acc: 0.8042 - val_loss: 0.5738 - val_acc: 0.8076
# Epoch 8/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.5264 - acc: 0.8193 - val_loss: 0.5423 - val_acc: 0.8220
# Epoch 9/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.4988 - acc: 0.8285 - val_loss: 0.8670 - val_acc: 0.7243
# Epoch 10/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.4787 - acc: 0.8342 - val_loss: 0.5382 - val_acc: 0.8205
# Epoch 11/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.4569 - acc: 0.8410 - val_loss: 0.6347 - val_acc: 0.7932
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.3947 - acc: 0.8642 - val_loss: 0.4726 - val_acc: 0.8452
# Epoch 13/50
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.3709 - acc: 0.8722 - val_loss: 0.4618 - val_acc: 0.8467
# Epoch 14/50
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.3535 - acc: 0.8794 - val_loss: 0.4778 - val_acc: 0.8443
# Epoch 15/50
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.3412 - acc: 0.8813 - val_loss: 0.4812 - val_acc: 0.8414
# Epoch 16/50
# 2000/2000 [==============================] - 53s 27ms/step - loss: 0.3300 - acc: 0.8861 - val_loss: 0.4971 - val_acc: 0.8417
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 17/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.3014 - acc: 0.8957 - val_loss: 0.4324 - val_acc: 0.8599
# Epoch 18/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.2885 - acc: 0.9015 - val_loss: 0.4417 - val_acc: 0.8569
# Epoch 19/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2799 - acc: 0.9042 - val_loss: 0.4298 - val_acc: 0.8615
# Epoch 20/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.2760 - acc: 0.9043 - val_loss: 0.4220 - val_acc: 0.8649
# Epoch 21/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2680 - acc: 0.9066 - val_loss: 0.4315 - val_acc: 0.8646
# Epoch 22/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2634 - acc: 0.9090 - val_loss: 0.4308 - val_acc: 0.8635
# Epoch 23/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.2592 - acc: 0.9117 - val_loss: 0.4335 - val_acc: 0.8629
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 24/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2369 - acc: 0.9186 - val_loss: 0.4250 - val_acc: 0.8677
# Epoch 25/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2345 - acc: 0.9203 - val_loss: 0.4255 - val_acc: 0.8701
# Epoch 26/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2295 - acc: 0.9219 - val_loss: 0.4220 - val_acc: 0.8700
# Epoch 27/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.2306 - acc: 0.9201 - val_loss: 0.4193 - val_acc: 0.8705
# Epoch 28/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2230 - acc: 0.9238 - val_loss: 0.4196 - val_acc: 0.8728
# Epoch 29/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2197 - acc: 0.9246 - val_loss: 0.4210 - val_acc: 0.8711
# Epoch 30/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2200 - acc: 0.9247 - val_loss: 0.4308 - val_acc: 0.8659
# Epoch 31/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2151 - acc: 0.9255 - val_loss: 0.4252 - val_acc: 0.8684
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 32/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.2103 - acc: 0.9285 - val_loss: 0.4267 - val_acc: 0.8693
# Epoch 33/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2044 - acc: 0.9295 - val_loss: 0.4238 - val_acc: 0.8687
# Epoch 34/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.2036 - acc: 0.9304 - val_loss: 0.4253 - val_acc: 0.8690
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 35/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.1991 - acc: 0.9314 - val_loss: 0.4253 - val_acc: 0.8691
# Epoch 36/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1948 - acc: 0.9326 - val_loss: 0.4236 - val_acc: 0.8700
# Epoch 37/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.2016 - acc: 0.9323 - val_loss: 0.4183 - val_acc: 0.8708
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 38/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1958 - acc: 0.9338 - val_loss: 0.4218 - val_acc: 0.8692
# Epoch 39/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1934 - acc: 0.9351 - val_loss: 0.4198 - val_acc: 0.8715
# Epoch 40/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1934 - acc: 0.9323 - val_loss: 0.4200 - val_acc: 0.8708
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 41/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1946 - acc: 0.9327 - val_loss: 0.4202 - val_acc: 0.8727
# Epoch 42/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1923 - acc: 0.9341 - val_loss: 0.4211 - val_acc: 0.8723
# Epoch 43/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.1928 - acc: 0.9326 - val_loss: 0.4209 - val_acc: 0.8726
# Epoch 44/50
# 2000/2000 [==============================] - 57s 29ms/step - loss: 0.1909 - acc: 0.9339 - val_loss: 0.4212 - val_acc: 0.8715
# Epoch 45/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1902 - acc: 0.9353 - val_loss: 0.4200 - val_acc: 0.8719
# Epoch 46/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1928 - acc: 0.9347 - val_loss: 0.4171 - val_acc: 0.8723
# Epoch 47/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1910 - acc: 0.9348 - val_loss: 0.4166 - val_acc: 0.8727
# Epoch 48/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1926 - acc: 0.9336 - val_loss: 0.4173 - val_acc: 0.8727
# Epoch 49/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1891 - acc: 0.9358 - val_loss: 0.4173 - val_acc: 0.8729
# Epoch 50/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.1897 - acc: 0.9346 - val_loss: 0.4181 - val_acc: 0.8716

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#saving the predictions probabilities
predict=model.predict(x_test)

# %%
import numpy as np
#Saving pridiction probability to answer presicted
predic={
    'probability':np.amax(predict,axis=1),
    'answer':np.argmax(predict,axis=1)
}

# %%
# Showing some examples
for x in range(18):
  plt.imshow(x_test[x][:])
  a="("+str(predic['probability'][x])+") ("+str(predic['answer'][x])+")"
  plt.xlabel(a)
  plt.show()

# %%
#saving the model
path = "../content/drive/My Drive/" 
model.save(path+'cifarMax_model.h5') 
model.save_weights(path+'cifarMax_model_weight.h5')
