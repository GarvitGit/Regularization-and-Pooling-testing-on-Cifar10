# %% [markdown]
# # Cifar 10 with Maxpool and Dropout Regularization

# %%
from keras.datasets import cifar10 #importing dataset
import keras
from keras.models import Sequential
from keras.layers import Activation,Conv2D,BatchNormalization,Dense,Flatten,MaxPooling2D,Dropout
import matplotlib.pyplot as plt # visualization
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#downloading data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 89s 1us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
i=50 # any random number would work between 0 and 49999
plt.imshow(x_train[i]) # To see the image
print(y_train[i]) # Corresponding output
# Out:
# [9]

# %%
# Time to change y to categorical for so that the outputs can be matched
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
# making the model
# input>conv2d>>relu>BatchNom>conv2d>relu>BatchNorm>MaxPool>Dropout
model=Sequential()

model.add(Conv2D(32,(3,3),padding='same',input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#>conv2d>>relu>BatchNom>conv2d>relu>BatchNorm>MaxPool>Dropout

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#flatten>Dense>BatchNorm>relu>Dropout>softmax(output)

model.add(Flatten())
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(10,activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# Checking the model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,679,658
# Trainable params: 1,678,250
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
# Setting up callback function
from keras.callbacks import EarlyStopping,ReduceLROnPlateau

early=EarlyStopping(patience=10) # if no changes are seen the model willstop training

reduce=ReduceLROnPlateau(monitor='val_acc',factor=0.5,patience=3,min_lr=0.00001,verbose=1) #if significant change is not seen
# the model will decrease the learning rate

callback=[early,reduce]

# %%
# Compiling the model
model.compile(loss='categorical_crossentropy', #loss function
              optimizer='adam', #here we are using adam optimizer
              metrics=['accuracy'])

# %%
# changing type to float
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# one value can vary upto 255
x_train /= 255
x_test /= 255

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# checking shape and initializing no of epochs and batch size
total_test=x_test.shape[0]
total_train=x_train.shape[0]
epochs=50
batch=25

# %%
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history=model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        validation_steps=total_test//batch,
                        steps_per_epoch=total_train//batch,
                        callbacks=callback,
                        workers=4)
# Out:
# Using real-time data augmentation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 2000/2000 [==============================] - 59s 30ms/step - loss: 1.4698 - acc: 0.4817 - val_loss: 0.9577 - val_acc: 0.6551
# Epoch 2/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 1.0681 - acc: 0.6202 - val_loss: 0.9797 - val_acc: 0.6559
# Epoch 3/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.9489 - acc: 0.6667 - val_loss: 0.7675 - val_acc: 0.7249
# Epoch 4/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.8753 - acc: 0.6951 - val_loss: 0.8054 - val_acc: 0.7132
# Epoch 5/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.8247 - acc: 0.7117 - val_loss: 0.7064 - val_acc: 0.7545
# Epoch 6/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.7966 - acc: 0.7237 - val_loss: 0.7016 - val_acc: 0.7574
# Epoch 7/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.7633 - acc: 0.7352 - val_loss: 0.5997 - val_acc: 0.7908
# Epoch 8/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.7377 - acc: 0.7440 - val_loss: 0.6639 - val_acc: 0.7671
# Epoch 9/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.7186 - acc: 0.7522 - val_loss: 0.6034 - val_acc: 0.7867
# Epoch 10/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.6961 - acc: 0.7601 - val_loss: 0.6287 - val_acc: 0.7868
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.6479 - acc: 0.7759 - val_loss: 0.6968 - val_acc: 0.7611
# Epoch 12/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.6159 - acc: 0.7868 - val_loss: 0.6171 - val_acc: 0.7889
# Epoch 13/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.6033 - acc: 0.7899 - val_loss: 0.5132 - val_acc: 0.8234
# Epoch 14/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.5935 - acc: 0.7953 - val_loss: 0.5966 - val_acc: 0.7994
# Epoch 15/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.5833 - acc: 0.7966 - val_loss: 0.4989 - val_acc: 0.8248
# Epoch 16/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.5857 - acc: 0.7979 - val_loss: 0.4873 - val_acc: 0.8290
# Epoch 17/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.5751 - acc: 0.8003 - val_loss: 0.5845 - val_acc: 0.8000
# Epoch 18/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.5716 - acc: 0.7998 - val_loss: 0.4904 - val_acc: 0.8295
# Epoch 19/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.5652 - acc: 0.8053 - val_loss: 0.4854 - val_acc: 0.8343
# Epoch 20/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.5539 - acc: 0.8116 - val_loss: 0.4712 - val_acc: 0.8362
# Epoch 21/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.5464 - acc: 0.8128 - val_loss: 0.4629 - val_acc: 0.8414
# Epoch 22/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.5423 - acc: 0.8105 - val_loss: 0.4925 - val_acc: 0.8308
# Epoch 23/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.5434 - acc: 0.8110 - val_loss: 0.4788 - val_acc: 0.8352
# Epoch 24/50
# 2000/2000 [==============================] - 54s 27ms/step - loss: 0.5369 - acc: 0.8167 - val_loss: 0.6256 - val_acc: 0.7891
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 25/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.5174 - acc: 0.8222 - val_loss: 0.4575 - val_acc: 0.8446
# Epoch 26/50
# 2000/2000 [==============================] - 55s 27ms/step - loss: 0.5038 - acc: 0.8260 - val_loss: 0.4634 - val_acc: 0.8427
# Epoch 27/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.5003 - acc: 0.8275 - val_loss: 0.4339 - val_acc: 0.8516
# Epoch 28/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.4965 - acc: 0.8293 - val_loss: 0.4298 - val_acc: 0.8499
# Epoch 29/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.4983 - acc: 0.8263 - val_loss: 0.4528 - val_acc: 0.8470
# Epoch 30/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.4936 - acc: 0.8308 - val_loss: 0.4694 - val_acc: 0.8411
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 31/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.4849 - acc: 0.8328 - val_loss: 0.4457 - val_acc: 0.8455
# Epoch 32/50
# 2000/2000 [==============================] - 55s 28ms/step - loss: 0.4725 - acc: 0.8371 - val_loss: 0.4350 - val_acc: 0.8484
# Epoch 33/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4779 - acc: 0.8369 - val_loss: 0.4312 - val_acc: 0.8523
# Epoch 34/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4731 - acc: 0.8357 - val_loss: 0.4284 - val_acc: 0.8542
# Epoch 35/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4725 - acc: 0.8380 - val_loss: 0.4215 - val_acc: 0.8552
# Epoch 36/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4672 - acc: 0.8381 - val_loss: 0.4395 - val_acc: 0.8499
# Epoch 37/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4631 - acc: 0.8402 - val_loss: 0.4316 - val_acc: 0.8517
# Epoch 38/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4664 - acc: 0.8413 - val_loss: 0.4158 - val_acc: 0.8580
# Epoch 39/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4626 - acc: 0.8412 - val_loss: 0.4597 - val_acc: 0.8429
# Epoch 40/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4677 - acc: 0.8399 - val_loss: 0.4241 - val_acc: 0.8569
# Epoch 41/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4605 - acc: 0.8434 - val_loss: 0.4327 - val_acc: 0.8527
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 42/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4538 - acc: 0.8439 - val_loss: 0.4241 - val_acc: 0.8552
# Epoch 43/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4582 - acc: 0.8413 - val_loss: 0.4258 - val_acc: 0.8529
# Epoch 44/50
# 2000/2000 [==============================] - 57s 28ms/step - loss: 0.4499 - acc: 0.8439 - val_loss: 0.4164 - val_acc: 0.8551
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 45/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4534 - acc: 0.8429 - val_loss: 0.4215 - val_acc: 0.8537
# Epoch 46/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4456 - acc: 0.8457 - val_loss: 0.4249 - val_acc: 0.8539
# Epoch 47/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4450 - acc: 0.8455 - val_loss: 0.4159 - val_acc: 0.8571
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 48/50
# 2000/2000 [==============================] - 56s 28ms/step - loss: 0.4488 - acc: 0.8460 - val_loss: 0.4173 - val_acc: 0.8556

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#saving the predictions probabilities
predict=model.predict(x_test)

# %%
import numpy as np
#Saving pridiction probability to answer presicted
predic={
    'probability':np.amax(predict,axis=1),
    'answer':np.argmax(predict,axis=1)
}

# %%
# Showing some examples
for x in range(18):
  plt.imshow(x_test[x][:])
  a="("+str(predic['probability'][x])+") ("+str(predic['answer'][x])+")"
  plt.xlabel(a)
  plt.show()

# %%
# Saving the model
path = "../content/drive/My Drive/" 
model.save(path+'cifarRegM_model.h5') 
model.save_weights(path+'cifarRegM_model_weight.h5')
